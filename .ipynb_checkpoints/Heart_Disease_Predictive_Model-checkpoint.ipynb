# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from xgboost import XGBClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('D:\Python\Jupyte_Notebook\Heart_Disease_Predictive-Model\Heart_Disease_Prediction.csv')

# %%
sns.countplot(x='Heart Disease', hue='Sex', data=df)
# Out:
# <Axes: xlabel='Heart Disease', ylabel='count'>

# %%
sns.countplot(x='Heart Disease', hue='Chest pain type', data=df)
# Out:
# <Axes: xlabel='Heart Disease', ylabel='count'>

# %%
sns.countplot(x='Sex', hue='Chest pain type', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.barplot(x='Sex', y='BP', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='BP'>

# %%
sns.barplot(x='Sex', y='Cholesterol', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Cholesterol'>

# %%
sns.barplot(x='Heart Disease', y='Cholesterol', data=df)
# Out:
# <Axes: xlabel='Heart Disease', ylabel='Cholesterol'>

# %%
sns.barplot(x='Heart Disease', y='BP', data=df)
# Out:
# <Axes: xlabel='Heart Disease', ylabel='BP'>

# %%
sns.lineplot(x='Age', y='BP', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='BP'>

# %%
sns.lineplot(x='Age', y='Cholesterol', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Cholesterol'>

# %%
sns.lineplot(x='Age', y='ST depression', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='ST depression'>

# %%
sns.barplot(x='Sex', y='ST depression', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='ST depression'>

# %%
sns.barplot(x='Heart Disease', y='Exercise angina', data=df)
# Out:
# <Axes: xlabel='Heart Disease', ylabel='Exercise angina'>

# %%
sns.barplot(x='Sex', y='Exercise angina', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Exercise angina'>

# %%
sns.barplot(x='Heart Disease', y='Number of vessels fluro', data=df)
# Out:
# <Axes: xlabel='Heart Disease', ylabel='Number of vessels fluro'>

# %%
sns.barplot(x='Heart Disease', y='Thallium', data=df)
# Out:
# <Axes: xlabel='Heart Disease', ylabel='Thallium'>

# %%
sns.barplot(x='Sex', y='FBS over 120', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='FBS over 120'>

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\anmol\AppData\Local\Temp\ipykernel_10896\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
le = LabelEncoder()

# %%
df['Heart Disease'] = le.fit_transform(df['Heart Disease'])
y = df.pop('Heart Disease')

# %%
x_train, x_test, y_train, y_test = train_test_split(df, y, random_state=0, test_size=0.2)

# %%
models = [
    ('Logistic Regression', LogisticRegression(max_iter=10000)),
    ('Random Forest', RandomForestClassifier()),
    ('XGBoost', XGBClassifier())
]

# %%
for name, model in models:
    model.fit(x_train, y_train)
    preds = model.predict(x_test)
    score = accuracy_score(y_test, preds)
    print(f"{name} accuracy score: {score:.3f}")
# Out:
# Logistic Regression accuracy score: 0.778
# Random Forest accuracy score: 0.815
# XGBoost accuracy score: 0.741
